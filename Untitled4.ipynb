# %%
import pandas as pd
import os

# %%
df=pd.read_excel('/home/youssef/Downloads/data.xlsx')
df2 = df.iloc[:, 0].str.split(',', expand=True)
df2=df2.iloc[:,0]
df2
path='/home/youssef/Downloads/plant_dataset/plantnet/images_test'
folders= sorted(os.listdir(path))

for i in range(1081):
    originale=path+'/'+folders[i]
    print("old file:",originale)
    new=path+'/'+df2[i]
    print("new file:",new)
    os.rename(originale,new)
# Out:
# old file: /home/youssef/Downloads/plant_dataset/plantnet/images_test/1355868
# new file: /home/youssef/Downloads/plant_dataset/plantnet/images_test/1355868_out
# old file: /home/youssef/Downloads/plant_dataset/plantnet/images_test/1355920
# new file: /home/youssef/Downloads/plant_dataset/plantnet/images_test/1355920_out
# old file: /home/youssef/Downloads/plant_dataset/plantnet/images_test/1355932
# new file: /home/youssef/Downloads/plant_dataset/plantnet/images_test/1355932_in
# old file: /home/youssef/Downloads/plant_dataset/plantnet/images_test/1355936
# new file: /home/youssef/Downloads/plant_dataset/plantnet/images_test/1355936_out
# old file: /home/youssef/Downloads/plant_dataset/plantnet/images_test/1355937
# new file: /home/youssef/Downloads/plant_dataset/plantnet/images_test/1355937_out
# old file: /home/youssef/Downloads/plant_dataset/plantnet/images_test/1355955
# new file: /home/youssef/Downloads/plant_dataset/plantnet/images_test/1355955_in
# ...

# %%
path='/home/youssef/Downloads/plant_dataset/ccc/plantnet_300K/images_test'
folders = sorted(os.listdir(path))
for i in folders:
        test=i.find("in")
#         if(test!=-1):
#         os.replace(path+'/'+folder, path+'/IN/'+folder)
i[10]
# Out:
# 't'
